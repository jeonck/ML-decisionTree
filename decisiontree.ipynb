# %%
# 필요한 라이브러리 임포트
from sklearn import datasets
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

# 데이터 로드 (iris 데이터셋 사용)
iris = datasets.load_iris()
X = iris.data  # 특성 데이터
y = iris.target  # 타겟 데이터 (분류할 클래스)

# 데이터를 학습용과 테스트용으로 분할 (70% 학습, 30% 테스트)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 의사 결정 트리 모델 생성 (깊이 3으로 제한)
clf = tree.DecisionTreeClassifier(max_depth=3, random_state=0)

# 모델 학습
clf.fit(X_train, y_train)

# 테스트 데이터로 예측 수행
y_pred = clf.predict(X_test)

# 모델 성능 평가
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# 결과 출력
print(f"정확도: {accuracy:.4f}")
print("혼동 행렬:")
print(conf_matrix)

# 결정 트리 시각화 (선택 사항)
plt.figure(figsize=(12, 8))
tree.plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
plt.title("의사 결정 트리 시각화")
plt.savefig("decision_tree.png")  # 이미지로 저장
plt.show()

# 정보 이득 확인 (특성 중요도)
feature_importance = clf.feature_importances_
for i, importance in enumerate(feature_importance):
    print(f"특성 {iris.feature_names[i]}: {importance:.4f} (중요도)")
# Out:
# 정확도: 1.0000
# 혼동 행렬:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
# /tmp/ipykernel_323/254216461.py:39: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   plt.savefig("decision_tree.png")  # 이미지로 저장
# /tmp/ipykernel_323/254216461.py:39: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   plt.savefig("decision_tree.png")  # 이미지로 저장
# /tmp/ipykernel_323/254216461.py:39: UserWarning: Glyph 44208 (\N{HANGUL SYLLABLE GYEOL}) missing from current font.
#   plt.savefig("decision_tree.png")  # 이미지로 저장
# /tmp/ipykernel_323/254216461.py:39: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   plt.savefig("decision_tree.png")  # 이미지로 저장
# /tmp/ipykernel_323/254216461.py:39: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   plt.savefig("decision_tree.png")  # 이미지로 저장
# ...
